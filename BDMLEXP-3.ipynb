# %% [markdown]
# Aim
#
# To implement a Decision Tree classifier using Python and evaluate its performance using Accuracy Score and Confusion Matrix on a real-world classification dataset.
#
# Description
#
# A Decision Tree is a supervised machine learning algorithm used for both classification and regression problems. In this experiment, a Decision Tree classifier is used to classify data into different categories based on the values of its input features.
#
# The Iris dataset can be used as the real-world dataset for this experiment. It contains measurements such as sepal length, sepal width, petal length, and petal width for three different species of iris flowers: Iris-setosa, Iris-versicolor, and Iris-virginica.
#
# The dataset is first divided into training and testing sets. The training data is used to build the Decision Tree model, while the test data is used to evaluate how well the model performs on unseen data. If necessary, preprocessing such as handling missing values or converting categorical data into numerical form is performed.
#
# The Decision Tree creates a series of decision rules by selecting suitable features and threshold values. These rules divide the dataset into smaller groups until the model reaches a prediction at a leaf node. For example, in the Iris dataset, the model may determine that a particular flower belongs to a specific species based on its petal measurements.
#
# After training, the model predicts the classes of the test data. Its performance is evaluated using two important metrics:
#
# Accuracy Score:
# Measures the percentage of test samples that are classified correctly.
#
# Accuracy=
# Total Predictions
# Correct Predictions
# 	​
#
#
# Confusion Matrix:
# Shows the number of correct and incorrect predictions for each class. It helps identify which classes are being predicted correctly and which classes are being confused with one another.
#
# The Decision Tree can also be visualized to understand the sequence of decisions made by the classifier. The visualization displays the features, decision conditions, class distributions, and leaf nodes of the tree, making the model easier to interpret.
#
# Working of the Experiment
#
# Dataset → Preprocessing → Train-Test Split → Decision Tree Training → Prediction → Accuracy & Confusion Matrix → Tree Visualization
#
# Expected Result
#
# The Decision Tree classifier should successfully classify the samples in the selected dataset with a good accuracy. The confusion matrix provides a detailed view of classification performance, while the tree visualization helps understand how the model makes its decisions.
#
# Conclusion
#
# Thus, a Decision Tree classifier was implemented using scikit-learn, trained on a real-world classification dataset, and evaluated using accuracy score and confusion matrix. The experiment demonstrates how Decision Trees can perform classification while also providing an interpretable representation of the decision-making process.

# %%
from sklearn.datasets import load_iris
from sklearn.tree import DecisionTreeClassifier,plot_tree
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix,accuracy_score
import matplotlib.pyplot as plt
import seaborn as sns
# Out:
# Running cells with 'Python 3.13.7' requires the ipykernel package.
#
# <a href='command:jupyter.createPythonEnvAndSelectController'>Create a Python Environment</a> with the required packages.
#
# Or install 'ipykernel' using the command: 'c:/Users/Lenovo/AppData/Local/Programs/Python/Python313/python.exe -m pip install ipykernel -U --user --force-reinstall'

# %%
iris = load_iris()
X = iris.data
y = iris.target

# %%
X_train,X_test,y_train,y_test = train_test_split(X,y, test_size=0.3, random_state=42)

# %%
dt_model = DecisionTreeClassifier(criterion="gini",random_state=0)
dt_model.fit(X_train,y_train)

# %%
y_pred=dt_model.predict(X_test)

# %%
cm=confusion_matrix(y_test,y_pred)
acc = accuracy_score(y_test,y_pred)
print("Confusion Matrix:\n",cm)
print("Accuracy Score:", acc)

# %%
sns.heatmap(cm, annot=True, cmap="Blues", xticklabels=iris.target_names,yticklabels=iris.target_names)
plt.xlabel("Predicted")
plt.ylabel("Actual")
plt.title("Confusion Matrix")
plt.show()

# %%
plt.figure(figsize=(12,8))
plot_tree(dt_model, filled=True,feature_names=iris.feature_names,class_names=iris.target_names)
plt.title("Decision Tree Visualization")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 plt.figure(figsize=(12,8))
#       2 plot_tree(dt_model, filled=True,feature_names=iris.feature_names,class_names=iris.target_names)
#       3 plt.title("Decision Tree Visualization")
#       4 plt.show()
#
# NameError: name 'plt' is not defined
